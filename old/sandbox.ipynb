# %%
from acrylic import Color
import streamlit as st

# %%
# layout:
#                                       ______________________________
title =                                          "Colormetry"
#                                       ______________________________
name_prompt, add_button_text =          "Enter a new idea: " , 'Add'
m1_prompt, m2_prompt, m3_prompt =   "Metric 1: ", "Metric 2: ", "Metric 3: "
#                                       ______________________________
#                                       thing X X X
#                                       thing X X X
#                                       thing X X X
#                                       thing X X X
#                                       thing X X X
#                                       ______________________________

# %%
m1_name = st.text_input(m1_prompt)
m2_name = st.text_input(m2_prompt)
m3_name = st.text_input(m3_prompt)
# Out:
# 2025-12-18 19:22:28.971 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-18 19:22:28.972 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-18 19:22:28.972 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-18 19:22:28.974 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-18 19:22:28.974 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# ...

# %%
m1 = st.number_input(m1_name, 5)
m2 = st.number_input(m2_name, 5)
m3 = st.number_input(m3_name, 5)
# Out:
# 2025-12-18 19:23:24.851 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-18 19:23:24.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-18 19:23:24.855 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Users/baptisteperrier/.pyenv/versions/3.10.6/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/baptisteperrier/.pyenv/versions/3.10.6/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/baptisteperrier/.pyenv/versions/3.10.6/envs/graveyard/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
# ...
